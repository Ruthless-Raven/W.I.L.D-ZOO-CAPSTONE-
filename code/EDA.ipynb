# %% [markdown]
# # This notebook was used to perform our exploratory data analysis (EDA)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Load data

# %%
EDA = pd.read_csv("../data/clean/full_dataset.csv")

# %%
EDA.head()
# Out:
#    ID Number Preferred Pronouns  Current Grade Level  Program  \
# 0     1489.0          masculine                  9.0  zoocamp
# 1     1489.0          masculine                  9.0  zoocamp
# 2     1489.0          masculine                  9.0  zoocamp
# 3     1489.0          masculine                  9.0  zoocamp
# 4     1489.0          masculine                  9.0  zoocamp
#
#    First Paying Job  Know employee  Applied Before  \
# 0                 1              0               0
# 1                 1              0               0
# 2                 1              0               0
# 3                 1              0               0
# 4                 1              0               0
#
#    Comfortable speaking to crowd Uncomfortable with  Extra activities  ...  \
# 0                            1.0      invertebrates                 0  ...
# 1                            1.0      invertebrates                 0  ...
# ...

# %%
EDA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783 entries, 0 to 782
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ID Number                      503 non-null    float64
#  1   Preferred Pronouns             752 non-null    object
#  2   Current Grade Level            780 non-null    float64
#  3   Program                        308 non-null    object
#  4   First Paying Job               783 non-null    int64
#  5   Know employee                  783 non-null    int64
#  6   Applied Before                 783 non-null    int64
#  7   Comfortable speaking to crowd  544 non-null    float64
#  8   Uncomfortable with             781 non-null    object
#  9   Extra activities               783 non-null    int64
#  10  Commit Summer                  766 non-null    object
#  11  Commit Weekday                 767 non-null    object
# ...

# %%
EDA["Rejected"].value_counts()
# Out:
# 0    503
# 1    280
# Name: Rejected, dtype: int64

# %%
print(EDA.describe())
# Out:
#          ID Number  Current Grade Level  First Paying Job  Know employee  \
# count   503.000000           780.000000        783.000000     783.000000
# mean   1296.230616             9.534615          0.830140       0.257982
# std     148.273512             0.938456          0.375749       0.437804
# min    1154.000000             8.000000          0.000000       0.000000
# 25%    1162.000000             9.000000          1.000000       0.000000
# 50%    1228.000000             9.000000          1.000000       0.000000
# 75%    1480.000000            10.000000          1.000000       1.000000
# max    1490.000000            12.000000          1.000000       1.000000
#
#        Applied Before  Comfortable speaking to crowd  Extra activities  \
# count      783.000000                     544.000000        783.000000
# mean         0.113665                       0.935662          0.197957
# std          0.317607                       0.245580          0.398714
# ...

# %%
Rejected = EDA[EDA["Rejected"]==1]
Rejected.describe()
# Out:
#        ID Number  Current Grade Level  First Paying Job  Know employee  \
# count        0.0           277.000000        280.000000     280.000000
# mean         NaN             9.736462          0.789286       0.221429
# std          NaN             1.035181          0.408546       0.415952
# min          NaN             8.000000          0.000000       0.000000
# 25%          NaN             9.000000          1.000000       0.000000
# 50%          NaN            10.000000          1.000000       0.000000
# 75%          NaN            10.000000          1.000000       0.000000
# max          NaN            12.000000          1.000000       1.000000
#
#        Applied Before  Comfortable speaking to crowd  Extra activities  \
# count      280.000000                     172.000000        280.000000
# mean         0.082143                       0.947674          0.150000
# std          0.275074                       0.223333          0.357711
# ...

# %%
Accepted = EDA[EDA["Rejected"]==0]
Accepted.describe()
# Out:
#          ID Number  Current Grade Level  First Paying Job  Know employee  \
# count   503.000000           503.000000        503.000000     503.000000
# mean   1296.230616             9.423459          0.852883       0.278330
# std     148.273512             0.861763          0.354575       0.448623
# min    1154.000000             8.000000          0.000000       0.000000
# 25%    1162.000000             9.000000          1.000000       0.000000
# 50%    1228.000000             9.000000          1.000000       0.000000
# 75%    1480.000000            10.000000          1.000000       1.000000
# max    1490.000000            11.000000          1.000000       1.000000
#
#        Applied Before  Comfortable speaking to crowd  Extra activities  \
# count      503.000000                     372.000000        503.000000
# mean         0.131213                       0.930108          0.224652
# std          0.337969                       0.255309          0.417768
# ...

# %% [markdown]
# ## Generate numeric feature distribution

# %%
numeric_features = EDA[['ID Number','Current Grade Level', 'First Paying Job', 'Know employee', 'Applied Before', 
'Comfortable speaking to crowd', 'Extra activities', 'Application Year', 'Current Age', 'Rejected', 'EECode', 'EarnHours',
'EarnRate', 'EarnAmount', 'EarnAmount', 'Year', 'Month'
]]

categorical_features = EDA[['Preferred Pronouns', 'Program', 'Uncomfortable with', 'Commit Summer', 'Commit Weekday', 'Hear about source',
'Dist Position Desc'
]]

# %%
numeric_features.hist(figsize=[30,30])
plt.suptitle("Numeric feature distribution")
plt.rcParams['font.size'] = '30'
plt.show()

# %% [markdown]
# ## Generate box plots of features

# %%
sns.boxplot(x='Rejected',y='Current Grade Level',data=EDA)
plt.show()
sns.boxplot(x='Rejected',y='Current Age',data=EDA)
plt.show()
sns.boxplot(x='Rejected',y='Application Year',data=EDA)
plt.show()
sns.boxplot(x='Rejected',y='First Paying Job',data=EDA)
plt.show()
sns.boxplot(x='Rejected',y='Know employee',data=EDA)
plt.show()

# %% [markdown]
# ## Generate feature distributions

# %%
sns.FacetGrid(EDA,hue="Rejected",height = 5).map(sns.distplot,"Know employee"). add_legend()
plt.show()
# Out:
# c:\Users\ihkim\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\ihkim\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(EDA,hue="Rejected",height = 5).map(sns.distplot,"Current Age"). add_legend()
plt.show()
# Out:
# c:\Users\ihkim\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\ihkim\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(EDA,hue="Rejected",height = 5).map(sns.distplot,"Application Year"). add_legend()
plt.show()
# Out:
# c:\Users\ihkim\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\ihkim\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(EDA,hue="Rejected",height = 5).map(sns.distplot,"First Paying Job"). add_legend()
plt.show()
# Out:
# c:\Users\ihkim\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\ihkim\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 'Preferred Pronouns', 'Program', 'Uncomfortable with', 'Commit Summer', 'Commit Weekday', 'Hear about source',
# 'Dist Position Desc'

# %%
counts = categorical_features["Dist Position Desc"].value_counts()
percent100 = categorical_features["Dist Position Desc"].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
light_conditions=pd.DataFrame({'counts': counts, 'Percent': percent100})
print(light_conditions)
counts = categorical_features["Uncomfortable with"].value_counts()
percent100 = categorical_features["Uncomfortable with"].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
light_conditions=pd.DataFrame({'counts': counts, 'Percent': percent100})
print(light_conditions)
counts = categorical_features["Commit Summer"].value_counts()
percent100 = categorical_features["Commit Summer"].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
acc_day=pd.DataFrame({'counts': counts, 'Percent': percent100})
print(acc_day)
counts = categorical_features["Commit Weekday"].value_counts()
percent100 = categorical_features["Commit Weekday"].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
acc_day=pd.DataFrame({'counts': counts, 'Percent': percent100})
print(acc_day)
# Out:
#                    counts Percent
# WILD Steward          373   74.3%
# WILD Ambassador       115   22.9%
# W.I.L.D. Champion      14    2.8%
#                counts Percent
# none              348   44.6%
# invertebrates     331   42.4%
# reptiles           68    8.7%
# mammals            22    2.8%
# birds              12    1.5%
#         counts Percent
# yes        713   93.1%
# unsure      53    6.9%
#         counts Percent
# yes        753   98.2%
# unsure      11    1.4%
# no           3    0.4%

# %%
selected_numeric_features = EDA[["Rejected","Current Age", "Application Year"]]
sns.set_style("whitegrid")
sns.pairplot(selected_numeric_features, hue = "Rejected", height = 5)
plt.show()

# %% [markdown]
# ## Generate correlation matrix

# %%
corr =  numeric_features.corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))
# Generate a custom diverging colormap
cmap = sns.diverging_palette(240, 10, n=9)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .8})
plt.show()
# Out:
# C:\Users\ihkim\AppData\Local\Temp\ipykernel_16604\3804582511.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr, dtype=np.bool)
